# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sklearn
from sklearn.linear_model import LinearRegression

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# データ可視化
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")
# %matplotlib inline

# グラフの日本語表記対応
from matplotlib import rcParams
rcParams["font.family"]     = "sans-serif"
rcParams["font.sans-serif"] = "Hiragino Maru Gothic Pro"

import os
for dirname, _, filenames in os.walk('/kaggle/input/novozymes-enzyme-stability-prediction'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session


def load_file(test_file, train_file):
#pandasでファイル読み込み
    test_data = pd.read_csv(test_file, index_col=0)
    train_data = pd.read_csv(train_file, index_col=0)

    return test_data,train_data

def make_vector(test_seq, train_seq):
    helix_list = ["A","E","L","M","Q","K","R","H"]
    sheet_list = ["V","I","Y","C","W","F","T"]
    other = ["G","N","P","S","D"]
#配列の長さ
#    sequence_length =  test_seq['protein_sequence'].map(lambda x: len(x))
    
#αヘリックスの構造を取りやすいアミノ酸
#   helix_amino_acid = test_seq['protein_sequence'].map(lambda x: (x.count('A'), x.count('E'), x.count('L'), x.count('M'), x.count('Q'), x.count('K'), x.count('R'), x.count('H')))

#βシートの構造を取りやすいアミノ酸
#    sheet_amino_acid = test_seq['protein_sequence'].map(lambda x: (x.count('V'), x.count('I'), x.count('Y'), x.count('C'), x.count('W'), x.count('F'), x.count('T')))

#その他
#    other_amino_acid = test_seq['protein_sequence'].map(lambda x: (x.count('G'), x.count('N'), x.count('P'), x.count('S'), x.count('D')))

#αヘリックスグループアミノ酸の合計
#    helix_group = test_seq['protein_sequence'].map(lambda x: x.count("A") + x.count("E") + x.count('L') + x.count('M') + x.count('Q') + x.count('K') + x.count('R') + x.count('H'))

#βシートグループアミノ酸の合計
#    sheet_group = test_seq['protein_sequence'].map(lambda x: (x.count('V') + x.count('I') + x.count('Y') + x.count('C') + x.count('W') + x.count('F') + x.count('T')))

    x_test = test_seq['protein_sequence'].map(lambda x: (len(x), x.count('A'), x.count('E'), x.count('L'), x.count('M'), x.count('Q'), x.count('K'), x.count('R'), x.count('H'), x.count('V'), x.count('I'), x.count('Y'), x.count('C'), x.count('W'), x.count('F'), x.count('T'), x.count('G'), x.count('N'), x.count('P'), x.count('S'), x.count('D'),x.count("A") + x.count("E") + x.count('L') + x.count('M') + x.count('Q') + x.count('K') + x.count('R') + x.count('H'),x.count('V') + x.count('I') + x.count('Y') + x.count('C') + x.count('W') + x.count('F') + x.count('T')))
    x_train = train_seq['protein_sequence'].map(lambda x: (len(x), x.count('A'), x.count('E'), x.count('L'), x.count('M'), x.count('Q'), x.count('K'), x.count('R'), x.count('H'), x.count('V'), x.count('I'), x.count('Y'), x.count('C'), x.count('W'), x.count('F'), x.count('T'), x.count('G'), x.count('N'), x.count('P'), x.count('S'), x.count('D'),x.count("A") + x.count("E") + x.count('L') + x.count('M') + x.count('Q') + x.count('K') + x.count('R') + x.count('H'),x.count('V') + x.count('I') + x.count('Y') + x.count('C') + x.count('W') + x.count('F') + x.count('T')))
    y_train = train_seq['tm']
    
    return x_test, x_train, y_train

def _main():
#inputファイル定義
    test_file = "/kaggle/input/novozymes-enzyme-stability-prediction/test.csv"
    train_file = "/kaggle/input/novozymes-enzyme-stability-prediction/train.csv"

#ファイル読み込み
    test_seq, train_seq = load_file(test_file,train_file)

# DataFrame作成
    df = pd.DataFrame(data=train_seq)
    dft =pd.DataFrame(data=test_seq)
    df.dropna(inplace=True)
    dft.dropna(inplace=True)
    X = df["pH"].values
    Y = df["tm"].values
    X_test = dft["pH"].values

# 次元の確認
    print(X.shape, Y.shape)
    X = X.reshape(-1, 1)
    print(X.shape)
    
    print(X_test.shape)
    X_test = X_test.reshape(-1, 1)
    print(X_test.shape)

# 学習する
    model = LinearRegression()
    model.fit(X, Y)
    print(model.coef_, model.intercept_)
    
# 予測する
    print(model.predict(X_test))

#特徴ベクトルの作成
    #x_test, x_train, y_train = make_vector(test_seq, train_seq)

if __name__ == "__main__":
    _main()
# Out:
# /kaggle/input/novozymes-enzyme-stability-prediction/sample_submission.csv
# /kaggle/input/novozymes-enzyme-stability-prediction/wildtype_structure_prediction_af2.pdb
# /kaggle/input/novozymes-enzyme-stability-prediction/train.csv
# /kaggle/input/novozymes-enzyme-stability-prediction/test.csv
# /kaggle/input/novozymes-enzyme-stability-prediction/train_updates_20220929.csv
# (27769,) (27769,)
# (27769, 1)
# (2413,)
# (2413, 1)
# [0.62668117] 47.06928448691815
# [52.08273388 52.08273388 52.08273388 ... 52.08273388 52.08273388
#  52.08273388]
